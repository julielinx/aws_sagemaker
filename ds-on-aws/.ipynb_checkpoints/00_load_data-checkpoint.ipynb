# %%
# !aws s3 cp --no-sign-request 's3://amazon-reviews-pds/tsv/amazon_reviews_us_Digital_Software_v1_00.tsv.gz' ./customer-reviews/
# Out:
# download: s3://amazon-reviews-pds/tsv/amazon_reviews_us_Digital_Software_v1_00.tsv.gz to customer-reviews/amazon_reviews_us_Digital_Software_v1_00.tsv.gz

# %%
# !aws s3 cp --no-sign-request 's3://amazon-reviews-pds/tsv/' ./customer-reviews/tsv/ --recursive
# Out:
# download: s3://amazon-reviews-pds/tsv/amazon_reviews_multilingual_JP_v1_00.tsv.gz to customer-reviews/tsv/amazon_reviews_multilingual_JP_v1_00.tsv.gz
# download: s3://amazon-reviews-pds/tsv/amazon_reviews_multilingual_FR_v1_00.tsv.gz to customer-reviews/tsv/amazon_reviews_multilingual_FR_v1_00.tsv.gz
# download: s3://amazon-reviews-pds/tsv/amazon_reviews_multilingual_DE_v1_00.tsv.gz to customer-reviews/tsv/amazon_reviews_multilingual_DE_v1_00.tsv.gz
# download: s3://amazon-reviews-pds/tsv/amazon_reviews_us_Apparel_v1_00.tsv.gz to customer-reviews/tsv/amazon_reviews_us_Apparel_v1_00.tsv.gz
# download: s3://amazon-reviews-pds/tsv/amazon_reviews_multilingual_UK_v1_00.tsv.gz to customer-reviews/tsv/amazon_reviews_multilingual_UK_v1_00.tsv.gz
# download: s3://amazon-reviews-pds/tsv/amazon_reviews_us_Automotive_v1_00.tsv.gz to customer-reviews/tsv/amazon_reviews_us_Automotive_v1_00.tsv.gz
# ...

# %%
# !aws s3 cp --no-sign-request 's3://amazon-reviews-pds/parquet' ./customer-reviews/ --recursive
# Out:
# download: s3://amazon-reviews-pds/parquet/product_category=Apparel/part-00004-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet to customer-reviews/product_category=Apparel/part-00004-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet
# download: s3://amazon-reviews-pds/parquet/product_category=Apparel/part-00000-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet to customer-reviews/product_category=Apparel/part-00000-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet
# download: s3://amazon-reviews-pds/parquet/product_category=Apparel/part-00001-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet to customer-reviews/product_category=Apparel/part-00001-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet
# download: s3://amazon-reviews-pds/parquet/product_category=Apparel/part-00003-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet to customer-reviews/product_category=Apparel/part-00003-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet
# ...

# %%
# !aws s3 cp ./customer-reviews/parquet 's3://data-science-on-aws-applied/customer-reviews/parquet/' --recursive
# Out:
# upload: customer-reviews/parquet/product_category=Apparel/part-00000-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet to s3://data-science-on-aws-applied/customer-reviews/parquet/product_category=Apparel/part-00000-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet
# upload: customer-reviews/parquet/product_category=Apparel/part-00004-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet to s3://data-science-on-aws-applied/customer-reviews/parquet/product_category=Apparel/part-00004-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet
# upload: customer-reviews/parquet/product_category=Apparel/part-00002-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet to s3://data-science-on-aws-applied/customer-reviews/parquet/product_category=Apparel/part-00002-495c48e6-96d6-4650-aa65-3c36a3516ddd.c000.snappy.parquet
# ...

# %%
# !aws s3 cp ./customer-reviews/tsv 's3://data-science-on-aws-applied/customer-reviews/tsv/' --recursive
# Out:
# upload: customer-reviews/tsv/amazon_reviews_multilingual_DE_v1_00.tsv.gz to s3://data-science-on-aws-applied/customer-reviews/tsv/amazon_reviews_multilingual_DE_v1_00.tsv.gz
# upload: customer-reviews/tsv/amazon_reviews_multilingual_UK_v1_00.tsv.gz to s3://data-science-on-aws-applied/customer-reviews/tsv/amazon_reviews_multilingual_UK_v1_00.tsv.gz
# upload: customer-reviews/tsv/amazon_reviews_multilingual_FR_v1_00.tsv.gz to s3://data-science-on-aws-applied/customer-reviews/tsv/amazon_reviews_multilingual_FR_v1_00.tsv.gz
# upload: customer-reviews/tsv/amazon_reviews_multilingual_JP_v1_00.tsv.gz to s3://data-science-on-aws-applied/customer-reviews/tsv/amazon_reviews_multilingual_JP_v1_00.tsv.gz
# upload: customer-reviews/tsv/amazon_reviews_us_Baby_v1_00.tsv.gz to s3://data-science-on-aws-applied/customer-reviews/tsv/amazon_reviews_us_Baby_v1_00.tsv.gz
# ...
